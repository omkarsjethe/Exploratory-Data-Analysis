# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import random

# %%
from datetime import datetime, timedelta
# Set a seed for reproducibility
random.seed(42)
np.random.seed(42)

# Generate fake data
num_rows = 150

data = {
    'Customer_ID': range(1, num_rows + 1),
    'Age': np.random.randint(18, 70, num_rows),
    'Gender': np.random.choice(['Male', 'Female'], num_rows),
    'Income': np.random.randint(20000, 120000, num_rows),
    'City': np.random.choice(['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix'], num_rows),
    'Purchase_Amount': np.random.uniform(50, 5000, num_rows).round(2),
    'Purchase_Date': [datetime(2023, 1, 1) + timedelta(days=random.randint(0, 364)) for _ in range(num_rows)],
    'Product_Category': np.random.choice(['Electronics', 'Clothing', 'Furniture', 'Toys', 'Books'], num_rows),
    'Loyalty_Status': np.random.choice(['Gold', 'Silver', 'Bronze', 'None'], num_rows)
}

# Create the DataFrame
df = pd.DataFrame(data)

# Introduce some missing values
missing_indices = np.random.choice(df.index, size=int(num_rows * 0.1), replace=False)
df.loc[missing_indices, 'Income'] = np.nan
missing_indices = np.random.choice(df.index, size=int(num_rows * 0.05), replace=False)
df.loc[missing_indices, 'Purchase_Amount'] = np.nan

# Display the first few rows of the DataFrame
df.head()
# Out:
#    Customer_ID  Age  Gender   Income         City  Purchase_Amount  \
# 0            1   56    Male  92082.0      Chicago          1446.07
# 1            2   69    Male  54754.0  Los Angeles           928.33
# 2            3   46    Male      NaN     New York          3765.54
# 3            4   32  Female  31411.0      Phoenix          4043.83
# 4            5   60  Female  22911.0      Houston          4953.00
#
#   Purchase_Date Product_Category Loyalty_Status
# 0    2023-11-24         Clothing           Gold
# 1    2023-02-27        Furniture           Gold
# 2    2023-01-13      Electronics         Silver
# 3    2023-05-21            Books           None
# 4    2023-05-06      Electronics         Silver

# %%
df.isna().sum()
# Out:
# Customer_ID          0
# Age                  0
# Gender               0
# Income              15
# City                 0
# Purchase_Amount      7
# Purchase_Date        0
# Product_Category     0
# Loyalty_Status       0
# dtype: int64

# %%
df["Income"].fillna(df["Income"].median(),inplace=True)

# %%
df["Purchase_Amount"].fillna(df["Purchase_Amount"].median(),inplace=True)

# %%
df.isna().sum()
# Out:
# Customer_ID         0
# Age                 0
# Gender              0
# Income              0
# City                0
# Purchase_Amount     0
# Purchase_Date       0
# Product_Category    0
# Loyalty_Status      0
# dtype: int64

# %%
sns.pairplot(data=df)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.scatterplot(data=df,x="Income",y="Age",hue="Gender")
plt.show()

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'Income', 'City', 'Purchase_Amount',
#        'Purchase_Date', 'Product_Category', 'Loyalty_Status'],
#       dtype='object')

# %%
sns.barplot(data=df,x="City",y="Income")
plt.show()

# %%
sns.histplot(df["Age"],kde=True)
plt.show()

# %%
sns.countplot(x="Gender",data=df)
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5372\2271070662.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'Income', 'City', 'Purchase_Amount',
#        'Purchase_Date', 'Product_Category', 'Loyalty_Status'],
#       dtype='object')

# %%
sns.countplot(data=df,x="Loyalty_Status")
plt.show()

# %%
sns.countplot(data=df,x="Product_Category")
plt.show()

# %%
df["Loyalty_Status"].value_counts()
# Out:
# Silver    42
# Gold      37
# None      36
# Bronze    35
# Name: Loyalty_Status, dtype: int64

# %%
sns.lineplot(data=df,x="Age",y="Income")
plt.show()

# %%
sns.barplot(data=df,y="Income",x="City")
plt.show()

# %%
sns.countplot(x="City",data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'Income', 'City', 'Purchase_Amount',
#        'Purchase_Date', 'Product_Category', 'Loyalty_Status'],
#       dtype='object')

# %%
sns.histplot(data=df,x="Purchase_Amount")
plt.show()

# %%
sns.lineplot(data=df,y="Income",x="Product_Category")
plt.show()

# %%
sns.scatterplot(data=df,x="Product_Category",y="Income",hue="Gender")
plt.show()

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'Income', 'City', 'Purchase_Amount',
#        'Purchase_Date', 'Product_Category', 'Loyalty_Status'],
#       dtype='object')

# %%
sns.scatterplot(data=df,x="City",y="Purchase_Amount",hue="Gender")
plt.show()
