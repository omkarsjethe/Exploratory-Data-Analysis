# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import warnings 
warnings.filterwarnings("ignore")

# %%
pwd
# Out:
# '/Users/omkarjethe/Desktop/Machine learning /EDA'

# %%
#importing dataset of zomato
df=pd.read_excel("zomato-2.xlsx")

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rate  votes            rest_type  \
# 0            Yes   4.1    775        Casual Dining
# 1             No   4.1    787        Casual Dining
# 2             No   3.8    918  Cafe, Casual Dining
# 3             No   3.7     88          Quick Bites
# 4             No   3.8    166        Casual Dining
# ...          ...   ...    ...                  ...
# 51712         No   3.6     27                  Bar
# 51713         No   3.7      0                  Bar
# 51714         No   3.7      0                  Bar
# 51715        Yes   4.3    236                  Bar
# 51716         No   3.4     13   Bar, Casual Dining
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 51712
# 51713
# 51714
# 51715                       Cocktails, Pizza, Buttermilk
# 51716
#
#                                      cuisines  approx_cost(for two people)  \
# 0              North Indian, Mughlai, Chinese                        800.0
# 1                 Chinese, North Indian, Thai                        800.0
# 2                      Cafe, Mexican, Italian                        800.0
# 3                  South Indian, North Indian                        300.0
# 4                    North Indian, Rajasthani                        600.0
# ...                                       ...                          ...
# 51712                             Continental                       1500.0
# 51713                             Finger Food                        600.0
# 51714                             Finger Food                       2000.0
# 51715                             Finger Food                       2500.0
# 51716  Finger Food, North Indian, Continental                       1500.0
#
#       listed_in(type) listed_in(city)
# 0              Buffet    Banashankari
# 1              Buffet    Banashankari
# 2              Buffet    Banashankari
# 3              Buffet    Banashankari
# 4              Buffet    Banashankari
# ...               ...             ...
# 51712   Pubs and bars      Whitefield
# 51713   Pubs and bars      Whitefield
# 51714   Pubs and bars      Whitefield
# 51715   Pubs and bars      Whitefield
# 51716   Pubs and bars      Whitefield
#
# [51717 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes', 'rest_type',
#        'dish_liked', 'cuisines', 'approx_cost(for two people)',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  float64
#  13  reviews_list                 51717 non-null  object
#  14  menu_item                    51717 non-null  object
#  15  listed_in(type)              51717 non-null  object
#  16  listed_in(city)              51717 non-null  object
# dtypes: float64(1), int64(1), object(15)
# memory usage: 6.7+ MB

# %%
 43942/51717 #percentage of values rate column
# Out:
# 0.8496625867703076

# %%
23639/51717 #percentage of dish liked column
# Out:
# 0.4570837442233695

# %%
df.shape
# Out:
# (51717, 17)

# %%
df.describe()
# Out:
#               votes  approx_cost(for two people)
# count  51717.000000                 51371.000000
# mean     283.697527                   555.431566
# std      803.838853                   438.850728
# min        0.000000                    40.000000
# 25%        7.000000                   300.000000
# 50%       41.000000                   400.000000
# 75%      198.000000                   650.000000
# max    16832.000000                  6000.000000

# %%
df.nunique()
# Out:
# url                            51717
# address                        11495
# name                            8792
# online_order                       2
# book_table                         2
# rate                              64
# votes                           2328
# phone                          12903
# location                          93
# rest_type                         93
# dish_liked                      5271
# cuisines                        2723
# approx_cost(for two people)       70
# reviews_list                   22456
# menu_item                       9098
# listed_in(type)                    7
# listed_in(city)                   30
# dtype: int64

# %%
#Removing the Unnecessary columns in dataset
df.drop(["url","address","phone","reviews_list","menu_item","location"],inplace=True,axis=1)

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes            rest_type  \
# 0            Yes   4.1/5    775        Casual Dining
# 1             No   4.1/5    787        Casual Dining
# 2             No   3.8/5    918  Cafe, Casual Dining
# 3             No   3.7/5     88          Quick Bites
# 4             No   3.8/5    166        Casual Dining
# ...          ...     ...    ...                  ...
# 51712         No  3.6 /5     27                  Bar
# 51713         No     NaN      0                  Bar
# 51714         No     NaN      0                  Bar
# 51715        Yes  4.3 /5    236                  Bar
# 51716         No  3.4 /5     13   Bar, Casual Dining
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 51712                                                NaN
# 51713                                                NaN
# 51714                                                NaN
# 51715                       Cocktails, Pizza, Buttermilk
# 51716                                                NaN
#
#                                      cuisines  approx_cost(for two people)  \
# 0              North Indian, Mughlai, Chinese                        800.0
# 1                 Chinese, North Indian, Thai                        800.0
# 2                      Cafe, Mexican, Italian                        800.0
# 3                  South Indian, North Indian                        300.0
# 4                    North Indian, Rajasthani                        600.0
# ...                                       ...                          ...
# 51712                             Continental                       1500.0
# 51713                             Finger Food                        600.0
# 51714                             Finger Food                       2000.0
# 51715                             Finger Food                       2500.0
# 51716  Finger Food, North Indian, Continental                       1500.0
#
#       listed_in(type) listed_in(city)
# 0              Buffet    Banashankari
# 1              Buffet    Banashankari
# 2              Buffet    Banashankari
# 3              Buffet    Banashankari
# 4              Buffet    Banashankari
# ...               ...             ...
# 51712   Pubs and bars      Whitefield
# 51713   Pubs and bars      Whitefield
# 51714   Pubs and bars      Whitefield
# 51715   Pubs and bars      Whitefield
# 51716   Pubs and bars      Whitefield
#
# [51717 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         51717 non-null  object
#  1   online_order                 51717 non-null  object
#  2   book_table                   51717 non-null  object
#  3   rate                         43942 non-null  object
#  4   votes                        51717 non-null  int64
#  5   rest_type                    51490 non-null  object
#  6   dish_liked                   23639 non-null  object
#  7   cuisines                     51672 non-null  object
#  8   approx_cost(for two people)  51371 non-null  float64
#  9   listed_in(type)              51717 non-null  object
#  10  listed_in(city)              51717 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 4.3+ MB

# %%
df.shape
# Out:
# (51717, 11)

# %%
df.duplicated().sum()
# Out:
# 124

# %%
df=df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         51717 non-null  object
#  1   online_order                 51717 non-null  object
#  2   book_table                   51717 non-null  object
#  3   rate                         43942 non-null  object
#  4   votes                        51717 non-null  int64
#  5   rest_type                    51490 non-null  object
#  6   dish_liked                   23639 non-null  object
#  7   cuisines                     51672 non-null  object
#  8   approx_cost(for two people)  51371 non-null  float64
#  9   listed_in(type)              51717 non-null  object
#  10  listed_in(city)              51717 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 4.3+ MB

# %%
df.head(15)
# Out:
#                                                  name online_order book_table  \
# 0                                               Jalsa          Yes        Yes
# 1                                      Spice Elephant          Yes         No
# 2                                     San Churro Cafe          Yes         No
# 3                               Addhuri Udupi Bhojana           No         No
# 4                                       Grand Village           No         No
# 5                                     Timepass Dinner          Yes         No
# 6     Rosewood International Hotel - Bar & Restaurant           No         No
# 7                                              Onesta          Yes        Yes
# 8                                      Penthouse Cafe          Yes         No
# 9                                           Smacznego          Yes         No
# 10  CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...          Yes         No
# 11                                       Cafe Shuffle          Yes        Yes
# 12                                   The Coffee Shack          Yes        Yes
# 13                                         Caf-Eleven           No         No
# 14                                    San Churro Cafe          Yes         No
#
#      rate  votes            rest_type  \
# 0   4.1/5    775        Casual Dining
# 1   4.1/5    787        Casual Dining
# 2   3.8/5    918  Cafe, Casual Dining
# 3   3.7/5     88          Quick Bites
# 4   3.8/5    166        Casual Dining
# 5   3.8/5    286        Casual Dining
# 6   3.6/5      8        Casual Dining
# 7   4.6/5   2556  Casual Dining, Cafe
# 8   4.0/5    324                 Cafe
# 9   4.2/5    504                 Cafe
# 10  4.1/5    402                 Cafe
# 11  4.2/5    150                 Cafe
# 12  4.2/5    164                 Cafe
# 13  4.0/5    424                 Cafe
# 14  3.8/5    918  Cafe, Casual Dining
#
#                                            dish_liked  \
# 0   Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1   Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2   Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                         Masala Dosa
# 4                                 Panipuri, Gol Gappe
# 5   Onion Rings, Pasta, Kadhai Paneer, Salads, Sal...
# 6                                                 NaN
# 7   Farmhouse Pizza, Chocolate Banana, Virgin Moji...
# 8   Pizza, Mocktails, Coffee, Nachos, Salad, Pasta...
# 9   Waffles, Pasta, Coleslaw Sandwich, Choco Waffl...
# 10  Waffles, Pasta, Crispy Chicken, Honey Chilli C...
# 11  Mocktails, Peri Fries, Lasagne, Pizza, Chicken...
# 12  Coffee, Spaghetti, Pancakes, Nachos, Pasta, Sa...
# 13  Sandwich, Omelette, Ice Tea, Virgin Mojito, Ho...
# 14  Churros, Cannelloni, Minestrone Soup, Hot Choc...
#
#                                        cuisines  approx_cost(for two people)  \
# 0                North Indian, Mughlai, Chinese                        800.0
# 1                   Chinese, North Indian, Thai                        800.0
# 2                        Cafe, Mexican, Italian                        800.0
# 3                    South Indian, North Indian                        300.0
# 4                      North Indian, Rajasthani                        600.0
# 5                                  North Indian                        600.0
# 6   North Indian, South Indian, Andhra, Chinese                        800.0
# 7                          Pizza, Cafe, Italian                        600.0
# 8                    Cafe, Italian, Continental                        700.0
# 9      Cafe, Mexican, Italian, Momos, Beverages                        550.0
# 10                                         Cafe                        500.0
# 11                   Cafe, Italian, Continental                        600.0
# 12          Cafe, Chinese, Continental, Italian                        500.0
# 13                            Cafe, Continental                        450.0
# 14                       Cafe, Mexican, Italian                        800.0
#
#    listed_in(type) listed_in(city)
# 0           Buffet    Banashankari
# 1           Buffet    Banashankari
# 2           Buffet    Banashankari
# 3           Buffet    Banashankari
# 4           Buffet    Banashankari
# 5           Buffet    Banashankari
# 6           Buffet    Banashankari
# 7            Cafes    Banashankari
# 8            Cafes    Banashankari
# 9            Cafes    Banashankari
# 10           Cafes    Banashankari
# 11           Cafes    Banashankari
# 12           Cafes    Banashankari
# 13           Cafes    Banashankari
# 14           Cafes    Banashankari

# %%
df.tail(25)
# Out:
#                                                     name online_order  \
# 51692                                  Amoeba Sports Bar          Yes
# 51693                                   One For The Road          Yes
# 51694                                  Whitefield Social          Yes
# 51695             The Whitefield Arms Pub & Microbrewery          Yes
# 51696                                    The Irish House           No
# 51697                           Shizusan Shophouse & Bar          Yes
# 51698         Kava Kitchen & Bar - Fairfield by Marriott           No
# 51699                                 Harry's Bar + Cafe          Yes
# 51700                                            BAR BAR           No
# 51701                                      The Beer Cafe          Yes
# 51702                                  Pablo's Gastrobar           No
# 51703                               Oliver's Pub & Diner          Yes
# 51704                                            Smaaash           No
# 51705                                 Izakaya Gastro Pub          Yes
# 51706                                           Red Glow           No
# 51707        M Bar - Bengaluru Marriott Hotel Whitefield           No
# 51708                             Keys Cafe - Keys Hotel           No
# 51709                         The Farm House Bar n Grill           No
# 51710                                       Topsy Turvey           No
# 51711                                            Bhagini           No
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes           rest_type  \
# 51692        Yes  3.9 /5    578         Lounge, Bar
# 51693        Yes  4.1 /5    137                 Bar
# 51694         No  4.1 /5   2773                 Pub
# 51695        Yes  4.2 /5   1113   Pub, Microbrewery
# 51696        Yes  4.3 /5   1776  Casual Dining, Pub
# 51697        Yes  4.4 /5   1313  Casual Dining, Bar
# 51698         No  3.9 /5     74  Casual Dining, Bar
# 51699        Yes  4.1 /5   1218                 Pub
# 51700        Yes  4.1 /5   1003  Bar, Casual Dining
# 51701        Yes  4.1 /5    673                 Pub
# 51702         No  4.0 /5   1094                 Bar
# 51703        Yes  3.9 /5    548  Pub, Casual Dining
# 51704        Yes  4.0 /5    189  Casual Dining, Pub
# 51705        Yes  3.8 /5    128  Bar, Casual Dining
# 51706         No  3.7 /5     27                 Pub
# 51707         No  3.9 /5     77    Fine Dining, Bar
# 51708         No  2.8 /5    161  Casual Dining, Bar
# 51709         No  3.7 /5     34  Casual Dining, Bar
# 51710         No     NaN      0                 Bar
# 51711         No  2.5 /5     81  Casual Dining, Bar
# 51712         No  3.6 /5     27                 Bar
# 51713         No     NaN      0                 Bar
# 51714         No     NaN      0                 Bar
# 51715        Yes  4.3 /5    236                 Bar
# 51716         No  3.4 /5     13  Bar, Casual Dining
#
#                                               dish_liked  \
# 51692  Pasta, Fish, Beer, Chicken Wings, Mocktails, G...
# 51693                             Cocktails, Pasta, Fish
# 51694  Cocktails, Chicken Kebab, Murgh Ghee Roast, Vi...
# 51695  Beer, Chicken Tikka, Cosmopolitan, Burgers, Co...
# 51696  Beer, Cocktails, Burgers, Chicken Nachos, Mock...
# 51697  California Roll, Cocktails, Mocktails, Maki Ro...
# 51698                                          Dal Halwa
# 51699  Cocktails, Beer, Long Island Iced Tea, Pasta, ...
# 51700  Mocktails, Cocktails, Pizza, Chicken Tikka, Na...
# 51701  Cocktails, Wheat Beer, Bruschettas, Pasta, Bur...
# 51702  Cocktails, Beer, Pizza, Long Island Iced Tea, ...
# 51703  Pizza, Beer, Cocktails, Nachos, Pasta, Moo Bur...
# 51704                                        Pizza, Beer
# 51705  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# 51706                                                NaN
# 51707                                   Rooftop Ambience
# 51708  Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# 51709                                                NaN
# 51710                                                NaN
# 51711                               Biryani, Andhra Meal
# 51712                                                NaN
# 51713                                                NaN
# 51714                                                NaN
# 51715                       Cocktails, Pizza, Buttermilk
# 51716                                                NaN
#
#                                                 cuisines  \
# 51692                               Continental, Chinese
# 51693             Continental, North Indian, Finger Food
# 51694  American, North Indian, Chinese, Finger Food, ...
# 51695                          British, Continental, BBQ
# 51696                                 European, American
# 51697  Asian, Japanese, Vietnamese, Korean, Chinese, ...
# 51698  North Indian, South Indian, Continental, Ameri...
# 51699                           Asian, American, Mexican
# 51700                 Continental, North Indian, Italian
# 51701        Finger Food, North Indian, Chinese, Italian
# 51702              Finger Food, American, Asian, Italian
# 51703  Finger Food, American, Continental, Burger, Pizza
# 51704                       North Indian, Pizza, Chinese
# 51705           North Indian, Continental, Mediterranean
# 51706                          North Indian, Continental
# 51707                                        Finger Food
# 51708                 Chinese, Continental, North Indian
# 51709                          North Indian, Continental
# 51710                                        Finger Food
# 51711        Andhra, South Indian, Chinese, North Indian
# 51712                                        Continental
# 51713                                        Finger Food
# 51714                                        Finger Food
# 51715                                        Finger Food
# 51716             Finger Food, North Indian, Continental
#
#        approx_cost(for two people) listed_in(type) listed_in(city)
# 51692                       1000.0   Pubs and bars      Whitefield
# 51693                       1200.0   Pubs and bars      Whitefield
# 51694                       1500.0   Pubs and bars      Whitefield
# 51695                       1600.0   Pubs and bars      Whitefield
# 51696                       1700.0   Pubs and bars      Whitefield
# 51697                       1800.0   Pubs and bars      Whitefield
# 51698                       1200.0   Pubs and bars      Whitefield
# 51699                       1200.0   Pubs and bars      Whitefield
# 51700                       1500.0   Pubs and bars      Whitefield
# 51701                       1400.0   Pubs and bars      Whitefield
# 51702                       1450.0   Pubs and bars      Whitefield
# 51703                       1500.0   Pubs and bars      Whitefield
# 51704                       1500.0   Pubs and bars      Whitefield
# 51705                       1200.0   Pubs and bars      Whitefield
# 51706                       1200.0   Pubs and bars      Whitefield
# 51707                       2000.0   Pubs and bars      Whitefield
# 51708                       1200.0   Pubs and bars      Whitefield
# 51709                        800.0   Pubs and bars      Whitefield
# 51710                        900.0   Pubs and bars      Whitefield
# 51711                        800.0   Pubs and bars      Whitefield
# 51712                       1500.0   Pubs and bars      Whitefield
# 51713                        600.0   Pubs and bars      Whitefield
# 51714                       2000.0   Pubs and bars      Whitefield
# 51715                       2500.0   Pubs and bars      Whitefield
# 51716                       1500.0   Pubs and bars      Whitefield

# %%
df.isna().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %% [markdown]
# # Step No 1 Cleaning Name column

# %%
df["name"].isnull().sum()
# Out:
# 0

# %%
df["name"].dtype
# Out:
# dtype('O')

# %%
df["name"].iloc[10]
# Out:
# 'CafÃ\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â© Down The Alley'

# %%
#creating user defined function to clean  name of resturant.
import re
def rest_names(names):
    if re.findall(r"[a-zA-Z0-9 ]",names):
        str_name1=re.findall(r"[a-zA-Z0-9 ]",names)
        str_name2="".join(str_name1)
        return str_name2
    else:
        return names

# %%
df["name"]=df["name"].astype(str)
df["name"]=df["name"].apply(rest_names)

# %%
df["name"][0:21]
# Out:
# 0                                             Jalsa
# 1                                    Spice Elephant
# 2                                   San Churro Cafe
# 3                             Addhuri Udupi Bhojana
# 4                                     Grand Village
# 5                                   Timepass Dinner
# 6     Rosewood International Hotel  Bar  Restaurant
# 7                                            Onesta
# 8                                    Penthouse Cafe
# 9                                         Smacznego
# 10                               Caf Down The Alley
# 11                                     Cafe Shuffle
# 12                                 The Coffee Shack
# 13                                        CafEleven
# 14                                  San Churro Cafe
# 15                                    Cafe Vivacity
# 16                                       Catchupino
# 17                                  Kirthis Biryani
# 18                                         T3H Cafe
# 19                    360 Atoms Restaurant And Cafe
# 20                                 The Vintage Cafe
# Name: name, dtype: object

# %%
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes', 'rest_type',
#        'dish_liked', 'cuisines', 'approx_cost(for two people)',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df["online_order"].value_counts()
# Out:
# Yes    30347
# No     21246
# Name: online_order, dtype: int64

# %% [raw]
# from the above datasets we can intercept that out of 51717 online ordering restaurants is 30347 and offline offering is 21246

# %% [markdown]
# # Step 2 Cleaning Of Rate Column

# %%
df["rate"].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df["rate"].nunique()
# Out:
# 64

# %%
df["rate"].isnull().sum()
# Out:
# 7775

# %%
#creating a function to replace 'new' and '-' with null values .
#also convert values from rate col from object to float datatype.
def rest_rate(rates):
    if(rates=="NEW" or rates=="-"):
        return np.nan
    else:
        rate_sp=float(str(rates).split("/")[0])
        return rate_sp

# %%
df["rate"]=df["rate"].apply(rest_rate)

# %%
df["rate"].unique()
# Out:
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, nan, 2.9, 3.5, 2.6, 3.4, 4.5, 2.5, 2.7, 4.7, 2.4, 2.2,
#        2.3, 4.8, 4.9, 2.1, 2. , 1.8])

# %%
#fill nan values with mean of rate column.
df["rate"].fillna(df["rate"].mean(),inplace=True)

# %%
df["rate"]
# Out:
# 0        4.100000
# 1        4.100000
# 2        3.800000
# 3        3.700000
# 4        3.800000
#            ...
# 51712    3.600000
# 51713    3.700449
# 51714    3.700449
# 51715    4.300000
# 51716    3.400000
# Name: rate, Length: 51717, dtype: float64

# %%
#created a lambda function to round numbers after decimal in rate column for easy to understand.
round_rate=lambda x:round(x,2)

# %%
df["rate"]
# Out:
# 0        4.100000
# 1        4.100000
# 2        3.800000
# 3        3.700000
# 4        3.800000
#            ...
# 51712    3.600000
# 51713    3.700449
# 51714    3.700449
# 51715    4.300000
# 51716    3.400000
# Name: rate, Length: 51717, dtype: float64

# %%
df["rate"]=df["rate"].apply(round_rate)

# %%
df["rate"]
# Out:
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 51712    3.6
# 51713    3.7
# 51714    3.7
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 51717, dtype: float64

# %%
df["rate"].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# name                               0
# online_order                       0
# book_table                         0
# rate                               0
# votes                              0
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %% [markdown]
# # Step 3 Cleaning the cost Column

# %%
df["approx_cost(for two people)"].unique()
# Out:
# array([ 800.,  300.,  600.,  700.,  550.,  500.,  450.,  650.,  400.,
#         900.,  200.,  750.,  150.,  850.,  100., 1200.,  350.,  250.,
#         950., 1000., 1500., 1300.,  199.,   80., 1100.,  160., 1600.,
#         230.,  130.,   50.,  190., 1700.,   nan, 1400.,  180., 1350.,
#        2200., 2000., 1800., 1900.,  330., 2500., 2100., 3000., 2800.,
#        3400.,   40., 1250., 3500., 4000., 2400., 2600.,  120., 1450.,
#         469.,   70., 3200.,   60.,  560.,  240.,  360., 6000., 1050.,
#        2300., 4100., 5000., 3700., 1650., 2700., 4500.,  140.])

# %%
#creating user defined fucntion to remove comma from cost and convert to float value.
def rest_cost(costs):
    costs=str(costs)
    if "," in costs:
        num_sp=costs.split(",")
        #print(num_sp)
        num_jo="".join(num_sp)
        #print(num_jo)
        num_flo=float(num_jo)
        return num_flo
    else:
        num_floco=float(costs)
        return num_floco

# %%
df["approx_cost(for two people)"]=df["approx_cost(for two people)"].apply(rest_cost)

# %%
# fill null values with mean value fo cost column.
df["approx_cost(for two people)"].fillna(df["approx_cost(for two people)"].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# name                               0
# online_order                       0
# book_table                         0
# rate                               0
# votes                              0
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)        0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %% [markdown]
# # Step 4 Cleaning Restraunt Column

# %%
df["rest_type"].unique()
# Out:
# array(['Casual Dining', 'Cafe, Casual Dining', 'Quick Bites',
#        'Casual Dining, Cafe', 'Cafe', 'Quick Bites, Cafe',
#        'Cafe, Quick Bites', 'Delivery', 'Mess', 'Dessert Parlor',
#        'Bakery, Dessert Parlor', 'Pub', 'Bakery', 'Takeaway, Delivery',
#        'Fine Dining', 'Beverage Shop', 'Sweet Shop', 'Bar',
#        'Beverage Shop, Quick Bites', 'Confectionery',
#        'Quick Bites, Beverage Shop', 'Dessert Parlor, Sweet Shop',
#        'Bakery, Quick Bites', 'Sweet Shop, Quick Bites', 'Kiosk',
#        'Food Truck', 'Quick Bites, Dessert Parlor',
#        'Beverage Shop, Dessert Parlor', 'Takeaway', 'Pub, Casual Dining',
#        'Casual Dining, Bar', 'Dessert Parlor, Beverage Shop',
#        'Quick Bites, Bakery', 'Dessert Parlor, Quick Bites',
#        'Microbrewery, Casual Dining', 'Lounge', 'Bar, Casual Dining',
#        'Food Court', 'Cafe, Bakery', nan, 'Dhaba',
#        'Quick Bites, Sweet Shop', 'Microbrewery',
#        'Food Court, Quick Bites', 'Pub, Bar', 'Casual Dining, Pub',
#        'Lounge, Bar', 'Food Court, Dessert Parlor',
#        'Casual Dining, Sweet Shop', 'Food Court, Casual Dining',
#        'Casual Dining, Microbrewery', 'Sweet Shop, Dessert Parlor',
#        'Bakery, Beverage Shop', 'Lounge, Casual Dining',
#        'Cafe, Food Court', 'Beverage Shop, Cafe', 'Cafe, Dessert Parlor',
#        'Dessert Parlor, Cafe', 'Dessert Parlor, Bakery',
#        'Microbrewery, Pub', 'Bakery, Food Court', 'Club',
#        'Quick Bites, Food Court', 'Bakery, Cafe', 'Bar, Cafe',
#        'Pub, Cafe', 'Casual Dining, Irani Cafee', 'Fine Dining, Lounge',
#        'Bar, Quick Bites', 'Bakery, Kiosk', 'Pub, Microbrewery',
#        'Microbrewery, Lounge', 'Fine Dining, Microbrewery',
#        'Fine Dining, Bar', 'Mess, Quick Bites', 'Dessert Parlor, Kiosk',
#        'Bhojanalya', 'Casual Dining, Quick Bites', 'Pop Up', 'Cafe, Bar',
#        'Casual Dining, Lounge', 'Bakery, Sweet Shop', 'Microbrewery, Bar',
#        'Cafe, Lounge', 'Bar, Pub', 'Lounge, Cafe', 'Club, Casual Dining',
#        'Quick Bites, Mess', 'Quick Bites, Meat Shop',
#        'Quick Bites, Kiosk', 'Lounge, Microbrewery',
#        'Food Court, Beverage Shop', 'Dessert Parlor, Food Court',
#        'Bar, Lounge'], dtype=object)

# %%
df["rest_type"].nunique()
# Out:
# 93

# %%
#replace null values with "" in type column.
df["rest_type"]=df["rest_type"].replace(np.nan,'')

# %%
df["rest_type"].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# name                               0
# online_order                       0
# book_table                         0
# rate                               0
# votes                              0
# rest_type                          0
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)        0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
df["rest_type"].unique()
# Out:
# array(['Casual Dining', 'Cafe, Casual Dining', 'Quick Bites',
#        'Casual Dining, Cafe', 'Cafe', 'Quick Bites, Cafe',
#        'Cafe, Quick Bites', 'Delivery', 'Mess', 'Dessert Parlor',
#        'Bakery, Dessert Parlor', 'Pub', 'Bakery', 'Takeaway, Delivery',
#        'Fine Dining', 'Beverage Shop', 'Sweet Shop', 'Bar',
#        'Beverage Shop, Quick Bites', 'Confectionery',
#        'Quick Bites, Beverage Shop', 'Dessert Parlor, Sweet Shop',
#        'Bakery, Quick Bites', 'Sweet Shop, Quick Bites', 'Kiosk',
#        'Food Truck', 'Quick Bites, Dessert Parlor',
#        'Beverage Shop, Dessert Parlor', 'Takeaway', 'Pub, Casual Dining',
#        'Casual Dining, Bar', 'Dessert Parlor, Beverage Shop',
#        'Quick Bites, Bakery', 'Dessert Parlor, Quick Bites',
#        'Microbrewery, Casual Dining', 'Lounge', 'Bar, Casual Dining',
#        'Food Court', 'Cafe, Bakery', '', 'Dhaba',
#        'Quick Bites, Sweet Shop', 'Microbrewery',
#        'Food Court, Quick Bites', 'Pub, Bar', 'Casual Dining, Pub',
#        'Lounge, Bar', 'Food Court, Dessert Parlor',
#        'Casual Dining, Sweet Shop', 'Food Court, Casual Dining',
#        'Casual Dining, Microbrewery', 'Sweet Shop, Dessert Parlor',
#        'Bakery, Beverage Shop', 'Lounge, Casual Dining',
#        'Cafe, Food Court', 'Beverage Shop, Cafe', 'Cafe, Dessert Parlor',
#        'Dessert Parlor, Cafe', 'Dessert Parlor, Bakery',
#        'Microbrewery, Pub', 'Bakery, Food Court', 'Club',
#        'Quick Bites, Food Court', 'Bakery, Cafe', 'Bar, Cafe',
#        'Pub, Cafe', 'Casual Dining, Irani Cafee', 'Fine Dining, Lounge',
#        'Bar, Quick Bites', 'Bakery, Kiosk', 'Pub, Microbrewery',
#        'Microbrewery, Lounge', 'Fine Dining, Microbrewery',
#        'Fine Dining, Bar', 'Mess, Quick Bites', 'Dessert Parlor, Kiosk',
#        'Bhojanalya', 'Casual Dining, Quick Bites', 'Pop Up', 'Cafe, Bar',
#        'Casual Dining, Lounge', 'Bakery, Sweet Shop', 'Microbrewery, Bar',
#        'Cafe, Lounge', 'Bar, Pub', 'Lounge, Cafe', 'Club, Casual Dining',
#        'Quick Bites, Mess', 'Quick Bites, Meat Shop',
#        'Quick Bites, Kiosk', 'Lounge, Microbrewery',
#        'Food Court, Beverage Shop', 'Dessert Parlor, Food Court',
#        'Bar, Lounge'], dtype=object)

# %%
df["rest_type"][df["rest_type"]=='']
# Out:
# 999
# 1300
# 1376
# 1565
# 1637
#         ..
# 50978
# 51130
# 51195
# 51294
# 51303
# Name: rest_type, Length: 227, dtype: object

# %%
df["rest_type"]
# Out:
# 0              Casual Dining
# 1              Casual Dining
# 2        Cafe, Casual Dining
# 3                Quick Bites
# 4              Casual Dining
#                 ...
# 51712                    Bar
# 51713                    Bar
# 51714                    Bar
# 51715                    Bar
# 51716     Bar, Casual Dining
# Name: rest_type, Length: 51717, dtype: object

# %% [markdown]
# # Step 5 cleaning cuisines column

# %%
df["cuisines"].unique()
# Out:
# array(['North Indian, Mughlai, Chinese', 'Chinese, North Indian, Thai',
#        'Cafe, Mexican, Italian', ...,
#        'North Indian, Street Food, Biryani', 'Chinese, Mughlai',
#        'North Indian, Chinese, Arabian, Momos'], dtype=object)

# %%
df["cuisines"].nunique()
# Out:
# 2723

# %%
df["cuisines"].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712    False
# 51713    False
# 51714    False
# 51715    False
# 51716    False
# Name: cuisines, Length: 51717, dtype: bool

# %%
#replace null values with "".
df["cuisines"]=df["cuisines"].replace(np.nan,'')

# %%
df.isnull().sum()
# Out:
# name                               0
# online_order                       0
# book_table                         0
# rate                               0
# votes                              0
# rest_type                          0
# dish_liked                     28078
# cuisines                           0
# approx_cost(for two people)        0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %% [markdown]
# # Step  6 cleaning dish liked  column

# %%
df["dish_liked"].unique()
# Out:
# array(['Pasta, Lunch Buffet, Masala Papad, Paneer Lajawab, Tomato Shorba, Dum Biryani, Sweet Corn Soup',
#        'Momos, Lunch Buffet, Chocolate Nirvana, Thai Green Curry, Paneer Tikka, Dum Biryani, Chicken Biryani',
#        'Churros, Cannelloni, Minestrone Soup, Hot Chocolate, Pink Sauce Pasta, Salsa, Veg Supreme Pizza',
#        ...,
#        'Noodles, Chicken Noodle, Momos, American Chopsuey, Salad, Manchow Soup, Manchurian',
#        'Chicken Quesadilla, Naan, Breakfast Buffet, Cheesecake, Cocktails, Lunch Buffet, Biryani',
#        'Biryani, Andhra Meal'], dtype=object)

# %%
df["dish_liked"].nunique()
# Out:
# 5271

# %%
df["dish_liked"].value_counts()
# Out:
#                                                                                                      28078
# Biryani                                                                                                182
# Chicken Biryani                                                                                         73
# Friendly Staff                                                                                          69
# Waffles                                                                                                 68
#                                                                                                      ...
# Butter Chicken, Shawarma Roll, Chicken Shawarama, Chicken Grill, Rolls, Al Faham Chicken, Biryani        1
# Filter Coffee, Sandwich, Bonda, Vada, Masala Dosa, Salad, Aloo Curry                                     1
# Burgers, Fries, Jumbo Royale Burger, Salads, Peri Peri Chicken Salad, Potato Wedges, Rolls               1
# Chaat, Pav Bhaji, Raj Kachori, Buttermilk, Ajwaini Paratha, Tawa Pulav, Sev Puri                         1
# Paratha, Dal Makhani, Lassi, Naan, Veg Thali, Chole, Kulcha                                              1
# Name: dish_liked, Length: 5272, dtype: int64

# %%
#replacing null values with "".
df["dish_liked"]=df["dish_liked"].replace(np.nan,"")

# %%
df["dish_liked"].isna().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %% [markdown]
# # EDA

# %% [markdown]
# # Data visualization (Graphs,piechart,etc)

# %% [markdown]
# # To know the top rated restraurant in the City according to the rating

# %%
high_vote=df.groupby("name")[["votes"]].mean().sort_values(by="votes",ascending=False).head(10).reset_index()

# %%
high_vote
# Out:
#                           name         votes
# 0  Byg Brewski Brewing Company  16588.500000
# 1                         Toit  14956.000000
# 2              The Black Pearl   9562.333333
# 3                  Big Pitcher   9164.500000
# 4        Arbor Brewing Company   8396.545455
# 5               Prost Brew Pub   7860.900000
# 6         Church Street Social   7561.727273
# 7                         Hoot   7257.000000
# 8    The Hole in the Wall Cafe   7124.875000
# 9                     Truffles   7001.372093

# %%
fig=plt.figure(figsize=(20,10))
sb.set_style(style="whitegrid")#whitegrid
sb.barplot(x="name",y="votes",data=high_vote)
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %%
high_rate=df.groupby("name")[["rate"]].mean().sort_values(by="rate",ascending=False).head(10).reset_index()

# %%
fig=plt.figure(figsize=(20,10))
sb.set_style(style="whitegrid")#whitegrid
sb.barplot(x="name",y="rate",data=high_rate,palette="husl")
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # To find the expensive hotels in city

# %%
high_cost=df.groupby(["name"])[["approx_cost(for two people)"]].mean().sort_values(by="approx_cost(for two people)",ascending=False).head(10).reset_index()

# %%
high_cost
# Out:
#                                      name  approx_cost(for two people)
# 0  Le Cirque Signature - The Leela Palace                       6000.0
# 1              Royal Afghan - ITC Windsor                       5000.0
# 2                  Malties - Radisson Blu                       4500.0
# 3              La Brasserie - Le Meridien                       4100.0
# 4          Masala Klub - The Taj West End                       4000.0
# 5            Alba - JW Marriott Bengaluru                       4000.0
# 6    Dum Pukht Jolly Nabobs - ITC Windsor                       4000.0
# 7                Riwaz - The Ritz-Carlton                       4000.0
# 8                   Dakshin - ITC Windsor                       4000.0
# 9     Edo Restaurant & Bar - ITC Gardenia                       4000.0

# %%
fig=plt.figure(figsize=(20,10))
sb.set_style(style="whitegrid")
sb.barplot(data=high_cost,y="approx_cost(for two people)",x="name",palette="tab10")
plt.xticks(rotation=60,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # To find the lowest cost restaurants

# %%
low_cost=df.groupby(["name"])[["approx_cost(for two people)"]].mean().sort_values(by="approx_cost(for two people)",ascending=False).tail(10).reset_index()

# %%
low_cost
# Out:
#                               name  approx_cost(for two people)
# 0                         Paanwadi                   100.000000
# 1  Shree Ganesh Fruit Juice Centre                    90.000000
# 2                        Dtink Lab                    80.000000
# 3                        Dosa Cafe                    80.000000
# 4                      Savera Cafe                    71.428571
# 5                          Namaste                    70.000000
# 6                Nellore Dosa Camp                    70.000000
# 7                       Funky Food                    60.000000
# 8                    Bread  Better                    50.000000
# 9            Srinidhi Sagar Deluxe                    40.000000

# %%
fig=plt.figure(figsize=(20,10))
sb.set_style(style="whitegrid")
sb.barplot(data=high_cost,y="approx_cost(for two people)",x="name",palette="tab10")
plt.xticks(rotation=60,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # To find the affordable hotels in city

# %%
afford_rest=df.groupby(["name"])[["approx_cost(for two people)","rate"]].mean()

# %%
afford_rest["approx_cost(for two people)"].mean()
# Out:
# 497.04129940991413

# %%
afford=afford_rest[(afford_rest["approx_cost(for two people)"]<afford_rest["approx_cost(for two people)"].mean()) & (afford_rest["rate"]>afford_rest["rate"].mean())].head(10).reset_index()

# %%
fig=plt.figure(figsize=(20,10))
sb.set_style(style="whitegrid")
sb.barplot(data=afford,y="approx_cost(for two people)",x="name",hue="rate")
plt.xticks(rotation=60,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # finding the rating of types of resturant(with and without book_table)

# %%
fig=plt.figure(figsize=(20,10))
sb.set_style(style="whitegrid")#whitegrid
sb.barplot(x="listed_in(type)",y="rate",data=df,hue="book_table",palette="rocket")
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # finding the rating of types of resturant(with and without online_order)

# %%
fig=plt.figure(figsize=(20,10))
sb.set_style(style="whitegrid")#whitegrid
sb.barplot(x="listed_in(type)",y="rate",data=df,hue="online_order")
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # finding the cost of two people for types of resturant(with or wtithout booking table)

# %%
fig=plt.figure(figsize=(20,10))
sb.set_style(style="whitegrid")#whitegrid
sb.barplot(x="listed_in(type)",y="approx_cost(for two people)",data=df,hue="book_table",palette="mako")
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Finding the cost of two people for types of resturant(with or wtithout online_order)

# %%
fig=plt.figure(figsize=(20,10))
sb.set_style(style="whitegrid")#whitegrid
sb.barplot(x="listed_in(type)",y="approx_cost(for two people)",data=df,hue="online_order",palette="magma")
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # finding how many votes does city recieved(with or without booking table)

# %%
fig=plt.figure(figsize=(20,10))
sb.set_style(style="whitegrid")#whitegrid
sb.barplot(x="listed_in(city)",y="votes",data=df,hue="book_table")
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Finding the percentage of rating for type of resturants.

# %%
types=df.groupby("listed_in(type)")["rate"].mean().reset_index()

# %%
fig=plt.figure(figsize=(10,10))
per_types=pd.Series(types["listed_in(type)"])
per_rate=pd.Series(types["rate"])
plt.pie(per_rate,labels=per_types,autopct="%1.1f%%")
plt.legend()
plt.show()

# %% [markdown]
# # Finding the percentage of cost of 2 people for city

# %%
city=df.groupby("listed_in(city)")["approx_cost(for two people)"].mean().reset_index()

# %%
fig=plt.figure(figsize=(10,10))
per_city=pd.Series(city["listed_in(city)"])
per_rate=pd.Series(city["approx_cost(for two people)"])
plt.pie(per_rate,labels=per_city,autopct="%1.1f%%")
plt.legend(bbox_to_anchor=(1.6, 0.6),loc='center right')
plt.show()

# %% [markdown]
# # Finfing the percentage of cost of 2 people for types of resturants

# %%
city=df.groupby("listed_in(type)")["approx_cost(for two people)"].mean().reset_index()

# %%
fig=plt.figure(figsize=(20,10))
per_city=pd.Series(city["listed_in(type)"])
per_rate=pd.Series(city["approx_cost(for two people)"])
plt.pie(per_rate,labels=per_city,autopct="%1.1f%%")
plt.legend(bbox_to_anchor=(1.6, 0.6),loc='center right')
plt.show()

# %% [markdown]
# # Finding the rating for cuisines.

# %%
cuisines=df.groupby("cuisines").mean().reset_index().iloc[1:31]

# %%
cuisines
# Out:
#                                              cuisines      rate        votes  \
# 1                                     African, Burger  4.590909   457.818182
# 2     African, Burger, Desserts, Beverages, Fast Food  4.600000   595.000000
# 3                                            American  3.564286    49.642857
# 4   American, Asian, Continental, North Indian, So...  4.100000   326.666667
# 5             American, Asian, European, North Indian  4.300000  3868.750000
# 6                                       American, BBQ  4.500000  5276.583333
# 7   American, Bakery, Beverages, Cafe, Healthy Foo...  3.700000     0.000000
# 8                         American, Burger, Fast Food  4.207143   289.000000
# 9                    American, Burger, Italian, Steak  3.900000  1338.000000
# 10                   American, Burger, Momos, Bengali  3.500000     9.000000
# 11         American, Cafe, Chinese, Italian, Desserts  3.700000     0.000000
# 12                        American, Cafe, Continental  4.400000   710.705882
# 13  American, Cafe, Continental, French, Burger, M...  4.500000   745.000000
# 14                                  American, Chinese  3.700000     0.000000
# 15       American, Chinese, Continental, North Indian  4.211111  2200.555556
# 16                              American, Continental  3.765625   788.718750
# 17                  American, Continental, BBQ, Steak  4.166667  3507.444444
# 18                     American, Continental, Chinese  4.100000   100.000000
# 19            American, Continental, Fast Food, Steak  4.095000  1310.750000
# 20                 American, Continental, Finger Food  3.900000   739.000000
# 21  American, Continental, North Indian, Mediterra...  4.650000  9164.500000
# 22         American, Continental, North Indian, Salad  4.500000  7860.900000
# 23  American, Continental, North Indian, South Indian  4.300000   156.285714
# 24                       American, Continental, Pizza  4.450000  2361.000000
# 25                       American, Continental, Salad  4.500000  8379.200000
# 26              American, Continental, Salad, Italian  3.700000     0.000000
# 27       American, Continental, Salad, Italian, Asian  3.700000     0.000000
# 28                       American, Continental, Steak  4.400000  2269.000000
# 29                American, Continental, Steak, Salad  4.000000   935.894737
# 30                                 American, European  4.366667   521.555556
#
#     approx_cost(for two people)
# 1                   1000.000000
# 2                   1000.000000
# 3                    717.857143
# 4                   1200.000000
# 5                   1400.000000
# 6                   2500.000000
# 7                    300.000000
# 8                    400.000000
# 9                   1700.000000
# 10                   400.000000
# 11                   400.000000
# 12                  1700.000000
# 13                   900.000000
# 14                   300.000000
# 15                  1200.000000
# 16                   465.625000
# 17                  1200.000000
# 18                   600.000000
# 19                  1375.000000
# 20                  1400.000000
# 21                  1800.000000
# 22                  1800.000000
# 23                  2800.000000
# 24                  2000.000000
# 25                  2000.000000
# 26                   400.000000
# 27                   400.000000
# 28                  1100.000000
# 29                  1000.000000
# 30                  2500.000000

# %%
fig=plt.figure(figsize=(20,10))
sb.barplot(x="cuisines",y="rate",data=cuisines,palette="tab10")
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Find th disliked dishes

# %%
dl=df.groupby("dish_liked").mean().reset_index().iloc[1:31]

# %%
fig=plt.figure(figsize=(20,10))
sb.barplot(x="dish_liked",y="rate",data=dl,palette="tab10")
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Finding the name of resturants have rating more than 4.5

# %%
rate_excellent=df[(df["rate"]>4.5)]

# %%
rate_excellent.groupby("name").mean().reset_index()
# Out:
#                               name      rate        votes  \
# 0               1131 Bar + Kitchen  4.600000  2785.000000
# 1        AB's - Absolute Barbecues  4.789474  4548.315789
# 2                 Apsara Ice Cream  4.600000   206.000000
# 3   Asia Kitchen By Mainland China  4.900000  2224.894737
# 4                       Baar Union  4.600000   641.000000
# ..                             ...       ...          ...
# 77               XO Belgian Waffle  4.600000   834.000000
# 78                        Yauatcha  4.600000  2353.666667
# 79                         You Mee  4.700000   261.666667
# 80                        Zamindar  4.600000   376.000000
# 81                         eat.fit  4.600000   498.833333
#
#     approx_cost(for two people)
# 0                   1500.000000
# 1                   1568.421053
# 2                    200.000000
# 3                   1500.000000
# 4                    850.000000
# ..                          ...
# 77                   400.000000
# 78                  2800.000000
# 79                  2000.000000
# 80                   800.000000
# 81                   500.000000
#
# [82 rows x 4 columns]

# %% [markdown]
# # find resturant where we have north inidan food & Chinese, Thai

# %%
north_indian=df[df["cuisines"].str.contains("North Indian")]

# %%
north_indian
# Out:
#                                name online_order book_table  rate  votes  \
# 0                             Jalsa          Yes        Yes   4.1    775
# 1                    Spice Elephant          Yes         No   4.1    787
# 3             Addhuri Udupi Bhojana           No         No   3.7     88
# 4                     Grand Village           No         No   3.8    166
# 5                   Timepass Dinner          Yes         No   3.8    286
# ...                             ...          ...        ...   ...    ...
# 51706                      Red Glow           No         No   3.7     27
# 51708        Keys Cafe - Keys Hotel           No         No   2.8    161
# 51709    The Farm House Bar n Grill           No         No   3.7     34
# 51711                       Bhagini           No         No   2.5     81
# 51716  The Nest - The Den Bengaluru           No         No   3.4     13
#
#                 rest_type                                         dish_liked  \
# 0           Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1           Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 3             Quick Bites                                        Masala Dosa
# 4           Casual Dining                                Panipuri, Gol Gappe
# 5           Casual Dining  Onion Rings, Pasta, Kadhai Paneer, Salads, Sal...
# ...                   ...                                                ...
# 51706                 Pub
# 51708  Casual Dining, Bar  Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# 51709  Casual Dining, Bar
# 51711  Casual Dining, Bar                               Biryani, Andhra Meal
# 51716  Bar, Casual Dining
#
#                                           cuisines  \
# 0                   North Indian, Mughlai, Chinese
# 1                      Chinese, North Indian, Thai
# 3                       South Indian, North Indian
# 4                         North Indian, Rajasthani
# 5                                     North Indian
# ...                                            ...
# 51706                    North Indian, Continental
# 51708           Chinese, Continental, North Indian
# 51709                    North Indian, Continental
# 51711  Andhra, South Indian, Chinese, North Indian
# 51716       Finger Food, North Indian, Continental
#
#        approx_cost(for two people) listed_in(type) listed_in(city)
# 0                            800.0          Buffet    Banashankari
# 1                            800.0          Buffet    Banashankari
# 3                            300.0          Buffet    Banashankari
# 4                            600.0          Buffet    Banashankari
# 5                            600.0          Buffet    Banashankari
# ...                            ...             ...             ...
# 51706                       1200.0   Pubs and bars      Whitefield
# 51708                       1200.0   Pubs and bars      Whitefield
# 51709                        800.0   Pubs and bars      Whitefield
# 51711                        800.0   Pubs and bars      Whitefield
# 51716                       1500.0   Pubs and bars      Whitefield
#
# [21085 rows x 11 columns]

# %%
north_indian_group=north_indian.groupby(["listed_in(type)"]).mean().reset_index()

# %%
fig=plt.figure(figsize=(20,10))
sb.barplot(x="listed_in(type)",y="approx_cost(for two people)",data=north_indian_group,palette="tab10")
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %%
chinese=df[df["cuisines"].str.contains("Chinese, Thai")]

# %%
chinese
# Out:
#                                        name online_order book_table  rate  \
# 37                          Szechuan Dragon          Yes         No   4.2
# 48                            Beijing Bites          Yes         No   3.7
# 57                                   Wamama          Yes        Yes   4.2
# 285                               Chung Wah          Yes         No   3.7
# 338                             The Trundle          Yes         No   3.7
# ...                                     ...          ...        ...   ...
# 51307                      The Kim Chi Chef          Yes         No   4.0
# 51635              Thai & Chinese Fast Food           No         No   3.4
# 51659              Shizusan Shophouse & Bar          Yes        Yes   4.4
# 51670  Miro Bar - Miraya Hotel & Residences           No         No   3.8
# 51697              Shizusan Shophouse & Bar          Yes        Yes   4.4
#
#        votes           rest_type  \
# 37      1647       Casual Dining
# 48       679       Casual Dining
# 57       354       Casual Dining
# 285      323       Casual Dining
# 338      133       Casual Dining
# ...      ...                 ...
# 51307    210       Casual Dining
# 51635      7         Quick Bites
# 51659   1313  Casual Dining, Bar
# 51670     26              Lounge
# 51697   1313  Casual Dining, Bar
#
#                                               dish_liked  \
# 37     Noodles, Momos, Veg Manchow Soup, Kung Pao Chi...
# 48     Momos, Dragon Chicken, Hakka Noodles, Chowmein...
# 57     Sushi, Noodles, Wine, Khau Suey, Mocktails, Ya...
# 285    Noodles, Veg Momos, Chowmein, Schezwan Fried R...
# 338    Salad, Mocktails, Chocolava, Pesto Pasta, Momo...
# ...                                                  ...
# 51307                        Noodle, Momos, Manchow Soup
# 51635
# 51659  California Roll, Cocktails, Mocktails, Maki Ro...
# 51670
# 51697  California Roll, Cocktails, Mocktails, Maki Ro...
#
#                                                 cuisines  \
# 37                                  Chinese, Thai, Momos
# 48                                         Chinese, Thai
# 57     Asian, Korean, Indonesian, Japanese, Chinese, ...
# 285                                 Chinese, Thai, Momos
# 338             Chinese, Thai, Continental, North Indian
# ...                                                  ...
# 51307                               Chinese, Thai, Momos
# 51635                                      Chinese, Thai
# 51659  Asian, Japanese, Vietnamese, Korean, Chinese, ...
# 51670                 North Indian, Chinese, Thai, Asian
# 51697  Asian, Japanese, Vietnamese, Korean, Chinese, ...
#
#        approx_cost(for two people)     listed_in(type) listed_in(city)
# 37                           600.0            Delivery    Banashankari
# 48                           850.0            Delivery    Banashankari
# 57                           800.0            Delivery    Banashankari
# 285                          850.0            Delivery    Banashankari
# 338                          700.0            Delivery    Banashankari
# ...                            ...                 ...             ...
# 51307                        900.0            Dine-out      Whitefield
# 51635                        400.0            Dine-out      Whitefield
# 51659                       1800.0  Drinks & nightlife      Whitefield
# 51670                       2000.0  Drinks & nightlife      Whitefield
# 51697                       1800.0       Pubs and bars      Whitefield
#
# [554 rows x 11 columns]

# %%
chinese_group=chinese.groupby(["listed_in(type)"]).mean().reset_index()

# %%
fig=plt.figure(figsize=(20,10))
sb.barplot(x="listed_in(type)",y="approx_cost(for two people)",data=chinese_group,palette="tab10")
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Find cost of 2 people for seafood in resturant.

# %%
fig=plt.figure(figsize=(20,10))
sb.barplot(x="name",y="approx_cost(for two people)",data=df[["name","approx_cost(for two people)","cuisines"]][df["cuisines"]=="Seafood"],palette="coolwarm")
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Find the rating of coffee for resturant

# %%
fig=plt.figure(figsize=(20,10))
sb.barplot(x="name",y="rate",data=df[["name","rate","dish_liked"]][df["dish_liked"]=="Coffee"],palette="coolwarm")
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # finding rating of pizza cuisines resturantwise.

# %%
fig=plt.figure(figsize=(20,10))
sb.barplot(x="name",y="rate",data=df[["name","rate","cuisines"]][df["cuisines"]=="Pizza"],palette="rocket")
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Find the rating of continental cuisines citywise.

# %%
fig=plt.figure(figsize=(20,10))
sb.barplot(x="listed_in(city)",y="rate",data=df[["listed_in(city)","rate","cuisines"]][df["cuisines"]=="Continental"],palette="tab10")
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Finding the rating of mutton and chicken biryani dish for type of resturants

# %%
fig=plt.figure(figsize=(20,10))
sb.barplot(x="listed_in(type)",y="rate",data=df[["listed_in(type)","rate","dish_liked"]][df["dish_liked"].isin(["Mutton Biryani","Chicken Biryani"])],hue="dish_liked",palette="tab10")
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Areawise cost of two people in bangalore.

# %%
fig=plt.figure(figsize=(20,10))
sb.set_style(style="whitegrid")#whitegrid
sb.barplot(x="listed_in(city)",y="approx_cost(for two people)",data=df)
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # location wise rating

# %%
fig=plt.figure(figsize=(20,10))
sb.set_style(style="whitegrid")#whitegrid
sb.barplot(x="listed_in(city)",y="rate",data=df,palette="Spectral")
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()

# %% [markdown]
# # finding how many votes does each loaction got

# %%
fig=plt.figure(figsize=(20,10))
sb.set_style(style="whitegrid")#whitegrid
sb.barplot(x="listed_in(city)",y="votes",data=df)
plt.xticks(rotation=40,horizontalalignment="right",fontsize="x-large")
plt.tight_layout()
plt.show()
